# %%
import pandas as pd
import numpy as np

# Carrega o arquivo Parquet
df = pd.read_parquet(r'data\processed\acidentes.parquet')

# Exibe as primeiras 5 linhas do arquivo
df.head()
# Out:
#        id data_inversa              tipo_acidente    dia_semana   fase_dia  \
# 0  652493   2025-01-01                 Tombamento  quarta-feira  Pleno dia
# 1  652519   2025-01-01            Colisăo frontal  quarta-feira  Pleno dia
# 2  652522   2025-01-01           Colisăo traseira  quarta-feira  Pleno dia
# 3  652544   2025-01-01  Saída de leito carroçável  quarta-feira  Pleno dia
# 4  652549   2025-01-01            Colisăo frontal  quarta-feira  Pleno dia
#
#                              causa_acidente   latitude  longitude
# 0  Reaçăo tardia ou ineficiente do condutor -23.485868 -46.540753
# 1                          Pista esburacada  -7.812288 -39.083333
# 2  Reaçăo tardia ou ineficiente do condutor -23.182565 -50.637228
# 3  Reaçăo tardia ou ineficiente do condutor -25.365177 -49.042230
# 4                   Velocidade Incompatível -16.468013 -43.431213

# %%
df.columns
# Out:
# Index(['id', 'data_inversa', 'tipo_acidente', 'dia_semana', 'fase_dia',
#        'causa_acidente', 'latitude', 'longitude'],
#       dtype='object')

# %%
df.dtypes
# Out:
# id                  int32
# data_inversa       object
# tipo_acidente      object
# dia_semana         object
# fase_dia           object
# causa_acidente     object
# latitude          float64
# longitude         float64
# dtype: object

# %%
for causa in df['tipo_acidente'].unique():
    print(causa)
# Out:
# Tombamento
# Colisăo frontal
# Colisăo traseira
# Saída de leito carroçável
# Incęndio
# Colisăo com objeto
# Colisăo lateral mesmo sentido
# Colisăo lateral sentido oposto
# Queda de ocupante de veículo
# Engavetamento
# Derramamento de carga
# Colisăo transversal
# Atropelamento de Pedestre
# Capotamento
# Atropelamento de Animal
# Eventos atípicos
# Sinistro pessoal de trânsito
